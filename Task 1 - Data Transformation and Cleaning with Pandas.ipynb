# %% [markdown]
# ### Step 0
# Load the energy data from the file `Energy Indicators.xls`, which is a list of indicators of [energy supply and renewable electricity production](Energy%20Indicators.xls) from the [United Nations](http://unstats.un.org/unsd/environment/excel_file_tables/2013/Energy%20Indicators.xls) for the year 2013, and should be put into a DataFrame with the variable name of **energy**.
#
# Keep in mind that this is an Excel file, and not a comma separated values file. Also, make sure to exclude the footer and header information from the datafile. The first two columns are unneccessary, so you should get rid of them, and you should change the column labels so that the columns are:
#
# `['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']`
#
# Convert `Energy Supply` to gigajoules (there are 1,000,000 gigajoules in a petajoule). For all countries which have missing data (e.g. data with "...") make sure this is reflected as `np.NaN` values.
#
# Rename the following list of countries (for use in later questions):
#
# ```"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"```
#
# There are also several countries with numbers and/or parenthesis in their name. Be sure to remove these,
#
# e.g.
#
# `'Bolivia (Plurinational State of)'` should be `'Bolivia'`,
#
# `'Switzerland17'` should be `'Switzerland'`.

# %%
import pandas as pd
import numpy as np

# %%
df_energy = pd.read_excel ('Energy Indicators.xls',
                           usecols= range(2,6),
                        skiprows = range(1,16),
                            skipfooter = 38,
                           na_values=['...'],
                                header = 1)

# %%
df_energy.head()
# Out:
#        Unnamed: 2 Energy Supply Energy Supply per capita  \
# 0             NaN    Petajoules               Gigajoules
# 1     Afghanistan           321                       10
# 2         Albania           102                       35
# 3         Algeria          1959                       51
# 4  American Samoa           NaN                      NaN
#
#   Renewable Electricity Production
# 0                                %
# 1                          78.6693
# 2                              100
# 3                          0.55101
# 4                         0.641026

# %%
df_energy= df_energy.drop([0])

# %%
df_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 1 to 227
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 2                        227 non-null    object
#  1   Energy Supply                     222 non-null    object
#  2   Energy Supply per capita          222 non-null    object
#  3   Renewable Electricity Production  227 non-null    object
# dtypes: object(4)
# memory usage: 8.9+ KB

# %%
df_energy.head()
# Out:
#        Unnamed: 2 Energy Supply Energy Supply per capita  \
# 1     Afghanistan           321                       10
# 2         Albania           102                       35
# 3         Algeria          1959                       51
# 4  American Samoa           NaN                      NaN
# 5         Andorra             9                      121
#
#   Renewable Electricity Production
# 1                          78.6693
# 2                              100
# 3                          0.55101
# 4                         0.641026
# 5                          88.6957

# %%
df_energy.rename(columns = {'Unnamed: 2':'Country', 
                              'Renewable Electricity Production':'% Renewable'}, inplace = True)
df_energy.head()
# Out:
#           Country Energy Supply Energy Supply per capita % Renewable
# 1     Afghanistan           321                       10     78.6693
# 2         Albania           102                       35         100
# 3         Algeria          1959                       51     0.55101
# 4  American Samoa           NaN                      NaN    0.641026
# 5         Andorra             9                      121     88.6957

# %%
df_energy['Energy Supply'] = df_energy['Energy Supply'].multiply(1000000)
                                        
df_energy.head()
# Out:
#           Country Energy Supply Energy Supply per capita % Renewable
# 1     Afghanistan     321000000                       10     78.6693
# 2         Albania     102000000                       35         100
# 3         Algeria    1959000000                       51     0.55101
# 4  American Samoa           NaN                      NaN    0.641026
# 5         Andorra       9000000                      121     88.6957

# %%
df_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 1 to 227
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   227 non-null    object
#  1   Energy Supply             222 non-null    object
#  2   Energy Supply per capita  222 non-null    object
#  3   % Renewable               227 non-null    object
# dtypes: object(4)
# memory usage: 8.9+ KB

# %%
df_energy['Country']=df_energy['Country'].str.replace(r'\d+', '')

# %%
df_energy.head()
# Out:
#           Country Energy Supply Energy Supply per capita % Renewable
# 1     Afghanistan     321000000                       10     78.6693
# 2         Albania     102000000                       35         100
# 3         Algeria    1959000000                       51     0.55101
# 4  American Samoa           NaN                      NaN    0.641026
# 5         Andorra       9000000                      121     88.6957

# %%
 df_energy.replace({'Country' : { 'Republic of Korea' : 'South Korea', 'United States of America' : 'United States', 'United Kingdom of Great Britain and Northern Ireland' : 'United Kingdom' ,'China, Hong Kong Special Administrative Region':'Hong Kong' }},inplace= True)

# %%
#df_energy['Country']=df_energy['Country'].split(" (")[0]
y = lambda i: i.split(" (")[0]
df_energy.Country =df_energy.Country.apply(y)

# %%
df_energy.loc[99,'Country']
# Out:
# 'Iran'

# %%
df_energy[df_energy['Country']=='Iran']
# Out:
#    Country Energy Supply Energy Supply per capita % Renewable
# 99    Iran    9172000000                      119     5.70772

# %% [markdown]
# # Step 1
# <br>
#
# Next, load the GDP data from the file `world_bank.csv`, which is a csv containing countries' GDP from 1960 to 2015 from [World Bank](http://data.worldbank.org/indicator/NY.GDP.MKTP.CD). Call this DataFrame **GDP**.
#
# Make sure to skip the header, and rename the following list of countries:
#
# ```"Korea, Rep.": "South Korea",
# "Iran, Islamic Rep.": "Iran",
# "Hong Kong SAR, China": "Hong Kong"```
#
# <br>

# %%
GDP = pd.read_csv('world_bank.csv' , skiprows = range(0,5), header=None  )

# %%
GDP.head()
# Out:
#             0    1                                         2               3   \
# 0        Aruba  ABW  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 1      Andorra  AND  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 2  Afghanistan  AFG  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 3       Angola  AGO  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 4      Albania  ALB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
#
#    4   5   6   7   8   9   ...            50            51            52  \
# 0 NaN NaN NaN NaN NaN NaN  ...           NaN           NaN           NaN
# 1 NaN NaN NaN NaN NaN NaN  ...  4.018196e+09  4.021331e+09  3.675728e+09
# 2 NaN NaN NaN NaN NaN NaN  ...  1.030523e+10  1.172119e+10  1.214448e+10
# 3 NaN NaN NaN NaN NaN NaN  ...  5.581103e+10  6.842044e+10  7.787420e+10
# 4 NaN NaN NaN NaN NaN NaN  ...  9.771760e+09  1.034829e+10  1.112752e+10
#
# ...

# %%
GDP.replace({0 : { "Korea, Rep.": "South Korea", "Iran, Islamic Rep.": "Iran","Hong Kong SAR, China": "Hong Kong" }},inplace= True)

# %%
GDP.tail()
# Out:
#                    0    1                                         2   \
# 259       Yemen, Rep.  YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa  ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.  COD  GDP at market prices (constant 2010 US$)
# 262            Zambia  ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe  ZWE  GDP at market prices (constant 2010 US$)
#
#                  3             4             5             6             7   \
# 259  NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 260  NY.GDP.MKTP.KD  7.707081e+10  8.003449e+10  8.497844e+10  9.124438e+10
# 261  NY.GDP.MKTP.KD  1.508024e+10  1.344383e+10  1.629401e+10  1.714358e+10
# 262  NY.GDP.MKTP.KD  4.592975e+09  4.655503e+09  4.539542e+09  4.688093e+09
# 263  NY.GDP.MKTP.KD  3.338344e+09  3.549199e+09  3.600111e+09  3.824915e+09
#
#                8             9   ...            50            51  \
# ...

# %% [markdown]
# ### Step 2
# Finally, load the [Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology](http://www.scimagojr.com/countryrank.php?category=2102) from the file `scimagojr-3.xlsx`, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame **ScimEn**.

# %%
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %% [markdown]
# ### Step 3
# Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
#
# The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations',
#        'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'].
#
# *This step should yeild a DataFrame with 20 columns and 15 entries.*

# %%
GDP_copy = GDP.copy()
energy_copy = df_energy.copy()
ScimEn_copy=ScimEn.copy()

# %%
GDP_copy=GDP_copy.drop(GDP_copy.columns[1:50] , axis=1)
GDP_copy
# Out:
#                    0             50            51            52            53  \
# 0               Aruba           NaN           NaN           NaN           NaN
# 1             Andorra  4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# 2         Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# 3              Angola  5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# 4             Albania  9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ..                ...           ...           ...           ...           ...
# 259       Yemen, Rep.  2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# 260      South Africa  3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# 261  Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# 262            Zambia  1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# 263          Zimbabwe  1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
# ...

# %%
GDP_copy.rename(columns={ GDP_copy.columns[0]: "Country" }, inplace = True)

# %%
GDP_copy.head()
# Out:
#        Country            50            51            52            53  \
# 0        Aruba           NaN           NaN           NaN           NaN
# 1      Andorra  4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# 2  Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# 3       Angola  5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# 4      Albania  9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
#
#              54            55            56            57            58  \
# 0  2.467704e+09           NaN           NaN           NaN           NaN
# 1  3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09           NaN
# 2  1.593680e+10  1.691113e+10  1.935220e+10  1.973134e+10  1.999032e+10
# 3  8.247091e+10  8.570262e+10  9.012096e+10  9.626143e+10  1.008863e+11
# 4  1.192695e+10  1.223109e+10  1.240477e+10  1.254247e+10  1.279331e+10
#
#              59
# 0           NaN
# 1           NaN
# 2  2.029415e+10
# 3  1.039106e+11
# 4  1.312082e+10

# %%
GDP_copy.set_index('Country' , inplace = True)

# %%
x=0
y=2006
for column in GDP_copy.columns:
    if x <11:
        GDP_copy.rename(columns={GDP_copy.columns[x]: y}, inplace = True)
        x=x+1
        y=y+1

# %%
GDP_copy.head()
# Out:
#                      2006          2007          2008          2009  \
# Country
# Aruba                 NaN           NaN           NaN           NaN
# Andorra      4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola       5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania      9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
#
#                      2010          2011          2012          2013  \
# Country
# Aruba        2.467704e+09           NaN           NaN           NaN
# Andorra      3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09
# Afghanistan  1.593680e+10  1.691113e+10  1.935220e+10  1.973134e+10
# Angola       8.247091e+10  8.570262e+10  9.012096e+10  9.626143e+10
# Albania      1.192695e+10  1.223109e+10  1.240477e+10  1.254247e+10
#
#                      2014          2015
# Country
# Aruba                 NaN           NaN
# ...

# %%
ScimEn_copy=ScimEn_copy.iloc[0:15,:]
ScimEn_copy
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
ScimEn_copy['Country'].isin (energy_copy['Country']).value_counts()
# Out:
# True    15
# Name: Country, dtype: int64

# %%
df_1 = pd.merge(ScimEn_copy,energy_copy, on='Country')
df_1.shape
# Out:
# (15, 11)

# %%
df_final = pd.merge(df_1,GDP_copy, on='Country')
df_final
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
df_final_copy = df_final.copy()

# %% [markdown]
# ### Step 4
# The previous question joined three datasets then reduced this to just the top 15 entries. When you joined the datasets, but before you reduced this to the top 15 items, how many entries did you lose?
#
# *This step should yield a single number.*

# %%
df_2 = pd.merge(ScimEn,df_energy , on='Country', how='left',indicator='outer')
df_2.shape
# Out:
# (191, 12)

# %%
df_trial = pd.merge(df_2,GDP_copy, on='Country',how='left')
df_trial.shape
# Out:
# (191, 22)

# %%
df_trial.shape[0]- df_final.shape[0]
# Out:
# 176

# %% [markdown]
# ### Step 5
#
# #### Answer the following questions in the context of only the top 15 countries by Scimagojr Rank
#
#
# What is the average GDP over the last 10 years for each country? (exclude missing values from this calculation.)
#
# *This step should return a Series named `avgGDP` with 15 countries and their average GDP sorted in descending order.*

# %%
avg = df_final.iloc[:,11:22]
avgGDP = avg.mean(axis=1).rename('avgGDP').sort_values(ascending= False)
avgGDP
# Out:
# 1     1.536434e+13
# 0     6.348609e+12
# 2     5.542208e+12
# 6     3.493025e+12
# 8     2.681725e+12
# 3     2.487907e+12
# 14    2.189794e+12
# 10    2.120175e+12
# 7     1.769297e+12
# 5     1.660647e+12
# 4     1.565459e+12
# 11    1.418078e+12
# 13    1.164043e+12
# 9     1.106715e+12
# 12    4.441558e+11
# Name: avgGDP, dtype: float64

# %% [markdown]
# ### Step  6
# What is the mean `Energy Supply per Capita`?
#
# *This step should return a single number.*

# %%
Energy_Supply_per_capita_mean= df_final['Energy Supply per capita'].mean()
print(' Energy Supply per capita mean is: {}'.format(Energy_Supply_per_capita_mean))
# Out:
#  Energy Supply per capita mean is: 157.6

# %% [markdown]
# ### Step 7
# What country has the maximum % Renewable and what is the percentage?
#
# *This step should return a tuple with the name of the country and the percentage.*

# %%
energy_Renewable_max=df_final[df_final['% Renewable']==df_final['% Renewable'].max()]
energy_Renewable_max = energy_Renewable_max[['Country' , '% Renewable']]
tuples= [tuple(x) for x in energy_Renewable_max.values]
tuples
# Out:
# [('Brazil', 69.64803)]

# %% [markdown]
# ### Step 8
# Create a new column that is the ratio of Self-Citations to Total Citations.
# What is the maximum value for this new column, and what country has the highest ratio?
#
# *This step should return a tuple with the name of the country and the ratio.*

# %%
df_final['citation_ratio']= df_final['Self-citations']/ df_final['Self-citations'].sum()
df_final
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
citation_ratio_max = df_final[df_final['citation_ratio']==df_final['citation_ratio'].max()]

# %%
citation_ratio_max = citation_ratio_max[['Country' , 'citation_ratio']]

# %%
citation_tuple = [tuple(x) for x in citation_ratio_max.values]
citation_tuple
# Out:
# [('China', 0.3937733982985838)]

# %% [markdown]
# ### Step 9
# Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
#
# *This step should return a series named `HighRenew` whose index is the country name sorted in ascending order of rank.*

# %%
median = df_final['% Renewable'].median()
median
# Out:
# 17.02028

# %%
df_final['HighRenew'] = [1 if x >=median else 0 for x in df_final['% Renewable']] 
df_final[['Country' ,'Rank' ,'HighRenew']]
# Out:
#                Country  Rank  HighRenew
# 0                China     1          1
# 1        United States     2          0
# 2                Japan     3          0
# 3       United Kingdom     4          0
# 4   Russian Federation     5          1
# 5               Canada     6          1
# 6              Germany     7          1
# 7                India     8          0
# 8               France     9          1
# 9          South Korea    10          0
# 10               Italy    11          1
# 11               Spain    12          1
# 12                Iran    13          0
# 13           Australia    14          0
# 14              Brazil    15          1

# %%
df_final['Population']= df_final['Energy Supply']/df_final['Energy Supply per capita']

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      15 non-null     int64
#  1   Country                   15 non-null     object
#  2   Documents                 15 non-null     int64
#  3   Citable documents         15 non-null     int64
#  4   Citations                 15 non-null     int64
#  5   Self-citations            15 non-null     int64
#  6   Citations per document    15 non-null     float64
#  7   H index                   15 non-null     int64
#  8   Energy Supply             15 non-null     object
#  9   Energy Supply per capita  15 non-null     object
#  10  % Renewable               15 non-null     object
#  11  2006                      15 non-null     float64
#  12  2007                      15 non-null     float64
# ...

# %%
df_final['Population'] = df_final.Population.astype(float)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      15 non-null     int64
#  1   Country                   15 non-null     object
#  2   Documents                 15 non-null     int64
#  3   Citable documents         15 non-null     int64
#  4   Citations                 15 non-null     int64
#  5   Self-citations            15 non-null     int64
#  6   Citations per document    15 non-null     float64
#  7   H index                   15 non-null     int64
#  8   Energy Supply             15 non-null     object
#  9   Energy Supply per capita  15 non-null     object
#  10  % Renewable               15 non-null     object
#  11  2006                      15 non-null     float64
#  12  2007                      15 non-null     float64
# ...

# %% [markdown]
# ### Step 10
# Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
#
# ```python
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```
#
# *This function should return a DataFrame with index named Continent `['Asia', 'Australia', 'Europe', 'North America', 'South America']` and columns `['size', 'sum', 'mean', 'std']`*

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'} 

df_Continent_dict = pd.DataFrame(ContinentDict.items() , columns=['Country', 'Continent'])
df_Continent = pd.merge(df_Continent_dict,df_final , on='Country')
df_Continent = df_Continent[['Country' , 'Continent','Population']]
df_Continent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     15 non-null     object
#  1   Continent   15 non-null     object
#  2   Population  15 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 480.0+ bytes

# %%
df_Continent= df_Continent.groupby(['Continent'])[.agg([np.size,np.mean,np.sum,np.std])
df_Continent
# Out:
#               Population
#                     size          mean           sum           std
# Continent
# Asia                 5.0  5.797333e+08  2.898666e+09  6.790979e+08
# Australia            1.0  2.331602e+07  2.331602e+07           NaN
# Europe               6.0  7.632161e+07  4.579297e+08  3.464767e+07
# North America        2.0  1.764276e+08  3.528552e+08  1.996696e+08
# South America        1.0  2.059153e+08  2.059153e+08           NaN
